# %% [markdown]
# <center> <h2> Project #2 </h2> </center>
# <center> <h3> SUPERSTORE BUSINESS ANALYSIS <h3> </center>

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('superstore1.csv')
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  01-06-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  01-05-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  01-05-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  01-08-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue   408      2.0
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed   120      3.0
# 2  Office Supplies      Storage      Tenex Box, Single Width    66      4.0
# 3  Office Supplies        Paper  Enermax Note Cards, Premium    45      3.0
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack   114      5.0
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
# 2       0.0   29.640           8.17            High  2011
# 3       0.5  -26.055           4.82            High  2011
# 4       0.1   37.770           4.70          Medium  2011
#
# [5 rows x 21 columns]

# %% [markdown]
# **LAST 5 RECORDS OF DATASET**

# %%
df.tail()
# Out:
#              order_id  order_date   ship_date       ship_mode  \
# 51285  CA-2014-115427  12/31/2014  01-04-2015  Standard Class
# 51286    MO-2014-2560  12/31/2014  01-05-2015  Standard Class
# 51287  MX-2014-110527  12/31/2014  01-02-2015    Second Class
# 51288  MX-2014-114783  12/31/2014  01-06-2015  Standard Class
# 51289  CA-2014-156720  12/31/2014  01-04-2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 51285        Erica Bern  Corporate        California  United States      US
# 51286         Liz Preis   Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton   Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen   Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias   Consumer          Colorado  United States      US
#
#         region  ...         category sub_category  \
# 51285     West  ...  Office Supplies      Binders
# 51286   Africa  ...  Office Supplies      Binders
# 51287  Central  ...  Office Supplies       Labels
# 51288    North  ...  Office Supplies       Labels
# 51289     West  ...  Office Supplies    Fasteners
#
#                                           product_name sales quantity  \
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14      2.0
# 51286          Wilson Jones Hole Reinforcements, Clear     4      1.0
# 51287           Hon Color Coded Labels, 5000 Label Set    26      3.0
# 51288           Hon Legal Exhibit Labels, Alphabetical     7      1.0
# 51289                              Bagged Rubber Bands     3      3.0
#
#        discount   profit  shipping_cost  order_priority  year
# 51285       0.2   4.5188           0.89          Medium  2014
# 51286       0.0   0.4200           0.49          Medium  2014
# 51287       0.0  12.3600           0.35          Medium  2014
# 51288       0.0   0.5600           0.20          Medium  2014
# 51289       0.2  -0.6048           0.17          Medium  2014
#
# [5 rows x 21 columns]

# %% [markdown]
# **ROWS AND COLUMNS OF DATASET**

# %%
df.shape
# Out:
# (51290, 21)

# %% [markdown]
# **HEADERS OF ALL THE COLUMNS**

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %% [markdown]
# **Check for any duplicate in Dataset**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_name, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, order_priority, year]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# None.

# %% [markdown]
# **DATA TYPES OF COLUMN**

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity          float64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %% [markdown]
# **Changing the Incorrect Data Types**

# %%
df['order_date'] = df['order_date'].astype('datetime64[ns]')
df['ship_date'] = df['ship_date'].astype('datetime64[ns]')
df['sales'] = pd.to_numeric(df['sales'], errors='coerce')

# %%
df.dtypes
# Out:
# order_id                  object
# order_date        datetime64[ns]
# ship_date         datetime64[ns]
# ship_mode                 object
# customer_name             object
# segment                   object
# state                     object
# country                   object
# market                    object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                    float64
# quantity                 float64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# order_priority            object
# year                       int64
# dtype: object

# %% [markdown]
# **Check for Null Values**

# %%
df.isnull().sum()
# Out:
# order_id             0
# order_date           0
# ship_date            0
# ship_mode            0
# customer_name        0
# segment              0
# state                0
# country              0
# market               0
# region               0
# product_id           0
# category             0
# sub_category         0
# product_name         0
# sales             3194
# quantity           186
# discount             0
# profit               0
# shipping_cost        0
# order_priority       0
# year                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %% [markdown]
# **Function return Series with number of distinct observations over requested axis**

# %%
df.nunique().sort_values()
# Out:
# category              3
# segment               3
# year                  4
# order_priority        4
# ship_mode             4
# market                7
# region               13
# quantity             13
# sub_category         17
# discount             27
# country             147
# customer_name       795
# sales               974
# state              1086
# order_date         1428
# ship_date          1464
# product_name       3741
# shipping_cost      7899
# product_id        10023
# profit            22220
# order_id          24196
# dtype: int64

# %% [markdown]
# **BASICS STATISTICS OF DATA**

# %%
df.describe()
# Out:
#               sales      quantity      discount        profit  shipping_cost  \
# count  47951.000000  47951.000000  47951.000000  47951.000000   47951.000000
# mean     159.348668      3.312569      0.145779     14.767158      17.382851
# std      200.036102      2.116508      0.215168     85.176484      28.265553
# min        0.000000      1.000000      0.000000  -1557.990000       0.000000
# 25%       29.000000      2.000000      0.000000      0.000000       2.410000
# 50%       76.000000      3.000000      0.000000      8.375400       6.930000
# 75%      205.000000      4.000000      0.200000     30.900000      19.910000
# max      999.000000     13.000000      0.850000    486.600000     427.100000
#
#                year
# count  47951.000000
# mean    2012.777439
# std        1.098628
# min     2011.000000
# 25%     2012.000000
# 50%     2013.000000
# 75%     2014.000000
# max     2014.000000

# %% [markdown]
# # **Q1: Which segment is the best seller?**

# %%
df["segment"].value_counts()
# Out:
# Consumer       24812
# Corporate      14413
# Home Office     8726
# Name: segment, dtype: int64

# %%
sns.countplot(x=df['segment'])
# Out:
# <AxesSubplot:xlabel='segment', ylabel='count'>

# %% [markdown]
# The Consumer Segment is the best seller.

# %% [markdown]
# # **Q2: Which Region has the highest order count and In which Region do we need to grow our Business?**

# %% [markdown]
# **Which region has the highest order count?**

# %%
df["region"].value_counts()
# Out:
# Central           10376
# South              6261
# EMEA               4818
# North              4465
# Africa             4389
# Oceania            3192
# West               3003
# Southeast Asia     2875
# East               2662
# North Asia         2096
# Central Asia       1838
# Caribbean          1609
# Canada              367
# Name: region, dtype: int64

# %% [markdown]
# Cental Region has the highest order count.

# %%
# sns.set(rc={'figure.figsize':(15,9)})
sns.countplot(x=df['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# The Business is performing great in the Central Region with highest order count but it needs to Expand it's Business in Canadian Region.

# %% [markdown]
# # **Q3: Who are the Top 10 Customers of the SuperStore and How much is their Repartition of the Profit?**

# %%
df['customer_name'].value_counts()[:10].plot(kind='barh',title='Customer Name & Product Ordered')
# Out:
# <AxesSubplot:title={'center':'Customer Name & Product Ordered'}>

# %%
customers = list(df['customer_name'].value_counts()[:10].index)
filters = df['customer_name'].isin(customers)
A = df[filters]

# %%
colors = sns.color_palette('pastel')[0:]


values = A.groupby('customer_name')['profit'].sum()
values
# Out:
# customer_name
# Art Ferguson           1097.17870
# Bill Eplett            2130.48490
# Chloris Kastensmidt     575.33174
# Eric Murdock           2442.68748
# Gary Hwang             1637.36290
# Harry Greene           1415.99372
# John Grady             2599.84010
# Muhammed Yedwab         488.46508
# Patrick O'Brill        1825.12550
# Steven Ward             811.30060
# Name: profit, dtype: float64

# %% [markdown]
# Harry Greene is in the list of Top 10 customers but he is actually in Negative which is a loss for our superstore.

# %%
A = A[A['customer_name'] != 'Harry Greene']

# %%
del customers[-2]

# %%
# plt.figure(figsize=(15,15))
values = A.groupby('customer_name')['profit'].sum()

plt.pie(values, labels = customers, colors = colors, autopct='%.0f%%')
plt.title("Repartition of the Profit for the top 9 Customer")
plt.show()

# %% [markdown]
# We were able to get the insight that Patrick O'Brill is Best customer and is providing the superstore with Profit of 21%

# %% [markdown]
# # **Q4: What are the Highest selling and Lowest Selling Sub-Category?**

# %%
print(df['sub_category'].value_counts())
# plt.figure(figsize=(12,6))
sns.countplot(x=df['sub_category'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Binders        6036
# Art            4806
# Storage        4804
# Paper          3500
# Furnishings    3122
# Chairs         3044
# Accessories    2912
# Phones         2899
# Labels         2583
# Envelopes      2413
# Fasteners      2395
# Supplies       2372
# Bookcases      2007
# Copiers        1789
# Appliances     1397
# Machines       1281
# Tables          591
# Name: sub_category, dtype: int64

# %% [markdown]
# **Q4(a)How much each Sub-Category is contributing in Sales of SuperStore?**

# %%
plt.figure(figsize=(15,10))
plt.pie(df['sub_category'].value_counts(),labels=df["sub_category"].value_counts().keys(),autopct="%0.1f%%")
plt.show()

# %% [markdown]
# # **Q5: What are the Top 10 States with highest Order Count?**

# %%
df['state'].value_counts().head(10)
# Out:
# California                1874
# England                   1369
# New York                  1042
# Texas                      948
# Ile-de-France              883
# New South Wales            705
# North Rhine-Westphalia     661
# Queensland                 650
# San Salvador               577
# Pennsylvania               557
# Name: state, dtype: int64

# %%
# plt.figure(figsize=(20,15))
df['state'].value_counts().head(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='state'>

# %% [markdown]
# # **6-Analyzing the Data by Country**

# %% [markdown]
# **CHECK FOR ALL THE COUNTRIES IN DATASET**

# %%
df['country'].unique()
# Out:
# array(['Algeria', 'Australia', 'Hungary', 'Sweden', 'Canada',
#        'New Zealand', 'Iraq', 'Philippines', 'United Kingdom', 'Malaysia',
#        'Guatemala', 'Iran', 'Thailand', 'Tanzania', 'Mexico', 'Cuba',
#        'France', 'Brazil', 'United States', 'Japan', 'Sudan', 'Taiwan',
#        'Indonesia', 'Vietnam', 'Angola', 'China', 'Mozambique', 'Lebanon',
#        'Singapore', 'Netherlands', 'Nigeria', 'Egypt', 'Venezuela',
#        'South Africa', 'Spain', 'India', 'Turkey', 'Austria', 'Italy',
#        'Germany', 'Nicaragua', 'Dominican Republic', 'Denmark',
#        'Saudi Arabia', 'Myanmar (Burma)', 'Zambia', 'Russia', 'Mongolia',
#        'Belgium', 'Kenya', 'El Salvador', 'Colombia', 'Estonia',
#        'Madagascar', 'Portugal', 'Morocco', 'Sierra Leone', 'Norway',
#        'Central African Republic', 'Czech Republic', 'Benin',
#        'Bangladesh', 'Panama', 'Chile', 'South Korea', 'Switzerland',
#        'Moldova', 'Uganda', 'Zimbabwe', 'Niger', 'Senegal', 'Hong Kong',
#        'Democratic Republic of the Congo', 'Poland', 'Ireland',
#        'Pakistan', 'Azerbaijan', 'Ukraine', 'Romania', 'Honduras',
#        'Israel', 'Cameroon', 'Cambodia', 'Georgia', 'Argentina',
#        'Finland', 'Lithuania', 'Peru', 'Somalia', 'Haiti',
#        "Cote d'Ivoire", 'Afghanistan', 'Guinea', 'Liberia', 'South Sudan',
#        'Turkmenistan', 'Kazakhstan', 'Lesotho', 'Burundi', 'Qatar',
#        'Bulgaria', 'Martinique', 'Croatia', 'Ghana', 'Rwanda', 'Ecuador',
#        'Paraguay', 'Ethiopia', 'Syria', 'Tajikistan', 'Slovakia',
#        'Belarus', 'Papua New Guinea', 'Togo', 'Libya', 'Djibouti',
#        'Yemen', 'United Arab Emirates', 'Barbados', 'Uzbekistan',
#        'Albania', 'Jamaica', 'Uruguay', 'Bolivia',
#        'Republic of the Congo', 'Swaziland', 'Kyrgyzstan',
#        'Guinea-Bissau', 'Bosnia and Herzegovina', 'Tunisia', 'Armenia',
#        'Jordan', 'Mali', 'Trinidad and Tobago', 'Namibia', 'Gabon',
#        'Macedonia', 'Nepal', 'Mauritania', 'Guadeloupe', 'Sri Lanka',
#        'Chad', 'Eritrea', 'Bahrain', 'Equatorial Guinea', 'Slovenia',
#        'Montenegro'], dtype=object)

# %% [markdown]
# **Q6(a)Look for Top 10 Consumer Countries**

# %%
df['country'].value_counts()[0:10]
# Out:
# United States     9402
# Australia         2584
# France            2569
# Mexico            2486
# Germany           1889
# China             1676
# Brazil            1507
# United Kingdom    1489
# India             1386
# Turkey            1348
# Name: country, dtype: int64

# %%
L1=["United States","Australia","France","Mexico","Germany","China","United Kingdom","Brazil","India","Indonesia"]
L2=[9994,2837,2827,2644,2065,1880,1633,1599,1555,1390]
sns.barplot(x=L2,y=L1)
sns.set_theme(style="darkgrid")
plt.title("Top 10 consumer countries in world")
plt.xlabel("count")
plt.ylabel("countries")
# Out:
# Text(0, 0.5, 'countries')

# %% [markdown]
# UNITED STATES IS THE LARGEST CONSUMER COUNTRY

# %% [markdown]
# **Q6(b)What are the Top 3 Consumer Countries orders as per Segment & Category?**

# %%
# Top 3 consumer countries orders as per categories & sub-categories
df_US=df[df["country"]=="United States"]
df_Aus=df[df["country"]=="Australia"]
df_FR=df[df["country"]=="France"]

# %%
#1st Largest Consumer Country "United States"
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=df_US["segment"],hue=df_US["category"])
# Out:
# <AxesSubplot:title={'center':'United States'}, xlabel='segment', ylabel='count'>

# %%
#2nd Largest Consumer Country "Australia"
plt.figure(figsize=(15,10))
plt.title("Australia")
sns.set_theme(style="darkgrid")
sns.countplot(x=df_Aus["segment"],hue=df_Aus["category"])
# Out:
# <AxesSubplot:title={'center':'Australia'}, xlabel='segment', ylabel='count'>

# %%
#2nd Largest Consumer Country "Australia"
plt.figure(figsize=(15,10))
plt.title("France")
sns.set_theme(style="darkgrid")
sns.countplot(x=df_FR["segment"],hue=df_FR["category"])
# Out:
# <AxesSubplot:title={'center':'France'}, xlabel='segment', ylabel='count'>

# %% [markdown]
# **What are the product needs of Top 3 countries as per Category & Sub-category?**

# %%
#1st largest consumer country "United States" 
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=df["category"],hue=df["sub_category"])
# Out:
# <AxesSubplot:title={'center':'United States'}, xlabel='category', ylabel='count'>

# %%
#2nd largest consumer country "Australia" 
plt.figure(figsize=(18,12))
plt.title("Australia")
sns.set_theme(style="darkgrid")
sns.countplot(x=df["category"],hue=df["sub_category"])
plt.legend(loc='upper right')

# %%
#3rd largest consumer country "France" 
plt.figure(figsize=(15,10))
plt.title("France")
sns.set_theme(style="darkgrid")
sns.countplot(x=df["category"],hue=df["sub_category"])
plt.legend(loc='upper right')

# %% [markdown]
# **In all 3 Top countries United States, Australia and France Office Supplies is the highest selling Category and with the Binders as highest selling Sub-Category.**

# %% [markdown]
# # **Q7: Growth of Superstore Sales over the year 2011-2014?**

# %%
df["year"].unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
df["year"].value_counts()
# Out:
# 2014    16391
# 2013    12895
# 2012    10267
# 2011     8398
# Name: year, dtype: int64

# %%
data = df.groupby(['year']).sum()

# %%
sns.barplot(data = data, x=data.index, y='quantity')
# Out:
# <AxesSubplot:xlabel='year', ylabel='quantity'>

# %% [markdown]
# **The Sales of the store has increased each year.**

# %% [markdown]
# #**8-Analyzing Profit**

# %% [markdown]
# **Q8(a) Anazlyzing Profit by each Category**

# %%
df["category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
categorical_profits = df.groupby('category').sum()[['profit']]
categorical_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")
# Out:
# Text(0, 0.5, 'In millions')

# %% [markdown]
# Technology is the most Profitable Category

# %% [markdown]
# **Q8(b) Analyzing Profit from each Market in the World**

# %%
market_profits = df.groupby('market').sum()[['profit']]
market_profits.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")
# Out:
# Text(0, 0.5, 'In millions')

# %% [markdown]
# From above Visual we can conclude that most of Profit is coming from APAC market followed by EU, US and LATAM markets

# %% [markdown]
# **Q8(c) Top 5 Profitable Countries?**

# %%
df.groupby(['country']).sum()[['profit']].sort_values(by="profit",ascending=False).nlargest(n=5, columns=['profit']).plot.bar(color="green")
plt.show()

# %% [markdown]
# The United States, China, India, United Kingdom and France are the Top 5 Profitable Countries.

# %% [markdown]
# # **Q9: What are the top 10 most selling Products?**

# %%
top_sp=pd.DataFrame(df.groupby(['product_name']).sum()['quantity'])
top_sp.sort_values('quantity',ascending=False)[:10]
# Out:
#                                        quantity
# product_name
# Staples                                   862.0
# Cardinal Index Tab, Clear                 337.0
# Eldon File Cart, Single Width             293.0
# Avery Index Tab, Clear                    252.0
# Ibico Index Tab, Clear                    251.0
# Sanford Pencil Sharpener, Water Color     245.0
# Stockwell Paper Clips, Assorted Sizes     243.0
# Stanley Pencil Sharpener, Water Color     242.0
# Acco Index Tab, Clear                     214.0
# Rogers File Cart, Single Width            209.0

# %%
# check top 10 products which have the highest sales

plt.figure(figsize=(10, 6))
sns.countplot(y='product_name', data=df, order=df['product_name'].value_counts().head(10).index, palette='viridis')
plt.title('Top 10 Products which have the highest count', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Product Name', fontsize=12)

plt.show()

# %% [markdown]
# # **Q10: What is the most preferred Shipment Mode?**

# %%
df['ship_mode'].value_counts()
# Out:
# Standard Class    28779
# Second Class       9655
# First Class        7013
# Same Day           2504
# Name: ship_mode, dtype: int64

# %%
df['ship_mode'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='ship_mode'>

# %% [markdown]
# # **Q11: In which Region the store is giving more discount and what is the most profitable region?**

# %%
regions= df.groupby(['region']).sum().sort_values('discount', ascending=False)
regions.reset_index(inplace=True)

fig, ax = plt.subplots(figsize=(15, 5))
sns.barplot(x='region', y='discount', data=regions)
plt.xticks(rotation=90)
plt.show();

# %%
df.groupby(['region']).sum()[['profit']].sort_values(by="profit",ascending=False).nlargest(n=5, columns=['profit']).plot.bar(color="green")
plt.show()

# %% [markdown]
# Super Store is offering high discounts in the Central Region and despite that, the Central region is still the most profitable Region.
